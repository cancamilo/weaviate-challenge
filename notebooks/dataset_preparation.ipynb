# %% [markdown]
# # Data preparation

# %%
# %load_ext autoreload
# %autoreload 2

import os
import sys

# Do this to enable importing modules
src_path = os.path.join(os.path.abspath(""), "..")
sys.path.insert(0, src_path)

from dotenv import load_dotenv, find_dotenv
load_dotenv(find_dotenv()) # read local .env file
# Out:
# True

# %%
import pandas as pd
df = pd.read_csv("../data/articles.csv")

# %%
USER_PROMPT = (
    f"I will give you batches of contents of articles. For each article, extract all named entities such as cryptocurrency, company, place, date, etc, into a list of objects with the properties entity_type and value"
    f"Please structure the answer in json format ready to be loaded by json.loads(). The answer should be a"
    f"list of objects only with fields called content and entities, where entities is the list described previously. For the content field, copy the number of the content only!."
    f"Please do not add any extra characters and make sure it is a list with objects in valid json format!\n"
)

class DataFormatter:
    @classmethod
    def format_data(cls, data_points: list, is_example: bool, start_index: int) -> str:
        text = ""
        for index, data_point in enumerate(data_points):
            if not is_example:
                text += f"Content number {start_index + index }\n"
            text += str(data_point) + "\n"
        return text

    @classmethod
    def format_batch(cls, context_msg: str, data_points: list, start_index: int) -> str:
        delimiter_msg = context_msg
        delimiter_msg += cls.format_data(data_points, False, start_index)
        return delimiter_msg

    @classmethod
    def format_prompt(cls, inference_posts: list, start_index: int):
        initial_prompt = USER_PROMPT
        initial_prompt += f"You must generate exactly a list of {len(inference_posts)} json objects, using the contents provided under CONTENTS FOR GENERATION\n"
        initial_prompt += cls.format_batch(
            "\nCONTENTS FOR GENERATION: \n", inference_posts, start_index
        )
        return initial_prompt

# %%
from openai import OpenAI
import logging
import json
logging.basicConfig(level=logging.INFO, format="%(asctime)s - %(levelname)s - %(message)s")

MAX_LENGTH = 16384
SYSTEM_PROMPT = "You are an asistant whose job is crypto traders make informed decisions based on market sentiment"

class OpenAIHandler:
    def __init__(self, gpt_model: str = "gpt-3.5-turbo"):
        self.api_key = os.getenv("OPENAI_API_KEY")
        self.gpt_model = gpt_model

    def request(self, prompt: str) -> list:
            try:
                client = OpenAI(api_key=self.api_key)
                logging.info("Sending batch to LLM")
                chat_completion = client.chat.completions.create(
                    messages=[
                        {"role": "system", "content": SYSTEM_PROMPT},
                        {"role": "user", "content": prompt[:MAX_LENGTH]},
                    ],
                    model=self.gpt_model,
                )
                response = chat_completion.choices[0].message.content
                return json.loads(self.clean_response(response))
            except Exception as e:
                logging.error(f"Skipping batch! An error occurred while communicating with API: {e}")
                return []

    @staticmethod
    def clean_response(response: str) -> str:
        start_index = response.find("[")
        end_index = response.rfind("]")
        return response[start_index : end_index + 1]

# %%
class DatasetGenerator:
    def __init__(
        self,
        api_communicator: OpenAIHandler,
        data_formatter: DataFormatter,
    ):
        self.api_communicator = api_communicator
        self.data_formatter = data_formatter

    def generate_training_data(self, df, batch_size: int = 1):
        
        response = []
        for i in range(0, len(df), batch_size):
            batch = df.iloc[i : i + batch_size]["content"].to_list()
            initial_prompt = self.data_formatter.format_prompt(batch, i)
            response += self.api_communicator.request(initial_prompt)
            for j in range(i, i + batch_size):
                response[j]["content"] = batch[j]

        # self.push_to_comet(response, collection_name)
        return response

# %%
batch = df.iloc[0 : 3]["content"].to_list()

# %%
# check prompt

test = df.iloc[0]["content"]
prompt = DataFormatter.format_prompt([test], 0)
import textwrap
# print(textwrap.fill(prompt, 150))
print(prompt)
# Out:
# I will give you batches of contents of articles. For each article, extract all named entities such as cryptocurrency, company, place, date, etc, into a list of objects with the properties entity_type and valuePlease structure the answer in json format ready to be loaded by json.loads(). The answer should be alist of objects only with fields called content and entities, where entities is the list described previously. For the content field, copy the number of the content only!.Please do not add any extra characters and make sure it is a list with objects in valid json format!
# You must generate exactly a list of 1 json objects, using the contents provided under CONTENTS FOR GENERATION
#
# CONTENTS FOR GENERATION:
# Content number 0
# Bitcoin  BTC  $68,460  dipped 2% on May 28 after wallets labeled as belonging to the collapsed crypto exchange Mt. Gox moved 107,547 BTC worth nearly $7.3 billion to an unknown wallet — with more transactions coming in by the hour.   BTC   $68,460  The move is ahead of the defunct crypto exchange’s plan to return BTC holdings to creditors before October. Blockchain tracking X account Whale Alert posted the moves in May 28 X posts, noting six on-chain transactions of between 3,999 BTC and 32,499 BTC within hours. Blockchain explorer Arkham Intelligence shows the the transaction hashes from 1:41 am to 4:46 am UTC include transfers from multiple Mt. Gox cold wallets, with most moving 2,000 BTC at a time. All transactions pointed to a single unlabeled address that holds 107,547 BTC worth nearly $7.29 billion at the time of writing. Mt. Gox trustee firm Nagashima Ohno and Tsunematsu did not immediately respond to an inquiry on where and why the Bitcoin was moved. Related: 3 tips for protecting Bitcoin profits amid Ethereum ETF mania Bitcoin dropped around 2% in the wake of the moving Mt. Gox BTC, it’s now trading at $67,875 compared to $69,374 at the time of the first transfer, according to CoinMarketCap. Last month, K33 Research analysts warned the move of Mt. Gox-era Bitcoin would “spook the market” and price-pressure the cryptocurrency. Over $9.4 billion worth of Bitcoin is owed to some of Mt. Gox’s 127,000 creditors who have waited to get it back for over ten years after the exchange collapsed in 2014 after multiple unnoticed hacks. Mt. Gox’s final repayment deadline is Oct. 31. Its trustee started contacting creditors in January to confirm their identity and exchange accounts for repayment.  Magazine: Blockchain detectives: Mt. Gox collapse saw birth of Chainalysis Update (May 28, 4:45 am UTC): This article has been updated to include details on an additional transfer and background information. Update (May 28, 5:55 am UTC): This article has been updated to add details about an additional transfer occurring at 4:46 am UTC. Add reaction

# %%
response = []
batch_size = 1
for i in range(0, len(df), batch_size):
    batch = df.iloc[i : i + batch_size]["content"].to_list()
    initial_prompt = DataFormatter.format_prompt(batch, i)
    response += OpenAIHandler().request(initial_prompt)

    # for j in range(i, i + batch_size):
    #     response[j]["content"] = batch[j]
# Out:
# 2024-05-28 13:50:03,381 - INFO - Sending batch to LLM
# 2024-05-28 13:50:12,108 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-05-28 13:50:12,125 - INFO - Sending batch to LLM
# 2024-05-28 13:50:16,997 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-05-28 13:50:17,015 - INFO - Sending batch to LLM
# 2024-05-28 13:50:25,522 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-05-28 13:50:25,537 - INFO - Sending batch to LLM
# 2024-05-28 13:50:30,436 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-05-28 13:50:30,452 - INFO - Sending batch to LLM
# 2024-05-28 13:50:35,456 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-05-28 13:50:35,485 - INFO - Sending batch to LLM
# 2024-05-28 13:50:39,346 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-05-28 13:50:39,364 - INFO - Sending batch to LLM
# 2024-05-28 13:50:41,496 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-05-28 13:50:41,511 - INFO - Sending batch to LLM
# 2024-05-28 13:50:48,459 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-05-28 13:50:48,474 - INFO - Sending batch to LLM
# 2024-05-28 13:50:58,919 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-05-28 13:50:58,923 - ERROR - Skipping batch! An error occurred while communicating with API: Expecting property name enclosed in double quotes: line 8 column 13 (char 163)
# 2024-05-28 13:50:58,939 - INFO - Sending batch to LLM
# 2024-05-28 13:51:09,860 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-05-28 13:51:09,881 - INFO - Sending batch to LLM
# 2024-05-28 13:51:14,885 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-05-28 13:51:14,900 - INFO - Sending batch to LLM
# 2024-05-28 13:51:21,292 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-05-28 13:51:21,301 - INFO - Sending batch to LLM
# 2024-05-28 13:51:29,818 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-05-28 13:51:29,835 - INFO - Sending batch to LLM
# 2024-05-28 13:51:36,588 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-05-28 13:51:36,606 - INFO - Sending batch to LLM
# 2024-05-28 13:51:41,613 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-05-28 13:51:41,633 - INFO - Sending batch to LLM
# 2024-05-28 13:51:44,883 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-05-28 13:51:44,903 - INFO - Sending batch to LLM
# 2024-05-28 13:51:51,641 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-05-28 13:51:51,659 - INFO - Sending batch to LLM
# 2024-05-28 13:51:57,939 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-05-28 13:51:57,951 - INFO - Sending batch to LLM
# 2024-05-28 13:51:59,425 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-05-28 13:51:59,445 - INFO - Sending batch to LLM
# 2024-05-28 13:52:04,749 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-05-28 13:52:04,784 - INFO - Sending batch to LLM
# 2024-05-28 13:52:07,513 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"

# %%
response
# Out:
# [{'content': '0',
#   'entities': [{'entity_type': 'cryptocurrency', 'value': 'Bitcoin'},
#    {'entity_type': 'cryptocurrency', 'value': 'BTC'},
#    {'entity_type': 'amount', 'value': '$68,460'},
#    {'entity_type': 'company', 'value': 'Mt. Gox'},
#    {'entity_type': 'amount', 'value': '107,547 BTC'},
#    {'entity_type': 'amount', 'value': '$7.3 billion'},
#    {'entity_type': 'date', 'value': 'May 28'},
#    {'entity_type': 'company', 'value': 'Whale Alert'},
#    {'entity_type': 'amount', 'value': '3,999 BTC'},
#    {'entity_type': 'amount', 'value': '32,499 BTC'},
#    {'entity_type': 'time', 'value': '1:41 am to 4:46 am UTC'},
#    {'entity_type': 'amount', 'value': '2,000 BTC'},
#    {'entity_type': 'amount', 'value': '$7.29 billion'},
#    {'entity_type': 'company', 'value': 'Arkham Intelligence'},
#    {'entity_type': 'company', 'value': 'Nagashima Ohno and Tsunematsu'},
#    {'entity_type': 'amount', 'value': '$67,875'},
#    {'entity_type': 'amount', 'value': '$69,374'},
#    {'entity_type': 'company', 'value': 'CoinMarketCap'},
#    {'entity_type': 'company', 'value': 'K33 Research'},
#    {'entity_type': 'amount', 'value': '$9.4 billion'},
#    {'entity_type': 'number', 'value': '127,000'},
#    {'entity_type': 'date', 'value': '2014'},
#    {'entity_type': 'date', 'value': 'Oct. 31'},
#    {'entity_type': 'date', 'value': 'May 28, 4:45 am UTC'},
#    {'entity_type': 'date', 'value': 'May 28, 5:55 am UTC'}]},
#  {'content': '1',
#   'entities': [{'entity_type': 'cryptocurrency', 'value': 'Ether'},
#    {'entity_type': 'cryptocurrency', 'value': 'ETH'},
#    {'entity_type': 'company', 'value': 'Grayscale'},
#    {'entity_type': 'company', 'value': 'Coinbase'},
#    {'entity_type': 'company', 'value': 'Kaiko'},
#    {'entity_type': 'organization',
#     'value': 'Securities and Exchange Commission'},
#    {'entity_type': 'date', 'value': 'Jan. 11'},
#    {'entity_type': 'date', 'value': 'May 27'},
#    {'entity_type': 'date', 'value': 'May 23'},
#    {'entity_type': 'date', 'value': 'May 1'},
#    {'entity_type': 'date', 'value': 'May 24'}]},
#  {'content': '2',
#   'entities': [{'entity_type': 'cryptocurrency', 'value': 'cryptocurrency'},
#    {'entity_type': 'company', 'value': 'REVOX'},
#    {'entity_type': 'technology', 'value': 'blockchain'},
#    {'entity_type': 'company', 'value': 'Cointelegraph'},
#    {'entity_type': 'person', 'value': 'Noam Chomsky'},
#    {'entity_type': 'person', 'value': 'Ben Bagdikian'},
#    {'entity_type': 'country', 'value': 'Indonesia'},
#    {'entity_type': 'language', 'value': 'English'},
#    {'entity_type': 'language', 'value': 'Japanese'},
#    {'entity_type': 'language', 'value': 'Korean'},
#    {'entity_type': 'language', 'value': 'Russian'},
#    {'entity_type': 'language', 'value': 'Indonesian'},
#    {'entity_type': 'language', 'value': 'Chinese'},
#    {'entity_type': 'language', 'value': 'Hindi'},
#    {'entity_type': 'language', 'value': 'Turkish'},
#    {'entity_type': 'language', 'value': 'Vietnamese'},
#    {'entity_type': 'person', 'value': 'Iran'},
#    {'entity_type': 'country', 'value': 'Iran'},
#    {'entity_type': 'company', 'value': 'Google Play'},
#    {'entity_type': 'country', 'value': 'Pakistan'},
#    {'entity_type': 'country', 'value': 'Nigeria'},
#    {'entity_type': 'social_media', 'value': 'Telegram'},
#    {'entity_type': 'business_model', 'value': 'token issuance'},
#    {'entity_type': 'exchange', 'value': 'Nigeria'},
#    {'entity_type': 'exchange', 'value': 'Indonesia'},
#    {'entity_type': 'industry_giant', 'value': 'LINE'},
#    {'entity_type': 'industry_giant', 'value': 'Japan Airlines'},
#    {'entity_type': 'technology', 'value': 'NFTs'}]},
#  {'content': '3',
#   'entities': [{'entity_type': 'company', 'value': 'Agora'},
#    {'entity_type': 'person', 'value': 'Nick van Eck'},
#    {'entity_type': 'company', 'value': 'Circle'},
#    {'entity_type': 'company', 'value': 'Coinbase'},
#    {'entity_type': 'company', 'value': 'Binance'},
#    {'entity_type': 'cryptocurrency', 'value': 'Dai (DAI)'},
#    {'entity_type': 'cryptocurrency', 'value': "Ethena's USDe"},
#    {'entity_type': 'cryptocurrency', 'value': "Mountain Protocol's USDM"},
#    {'entity_type': 'cryptocurrency', 'value': 'USDT'},
#    {'entity_type': 'cryptocurrency', 'value': 'USD Coin (USDC)'},
#    {'entity_type': 'cryptocurrency', 'value': 'Agora digital dollar (AUSD)'}]},
#  {'content': '4',
#   'entities': [{'entity_type': 'cryptocurrency', 'value': 'JENNER'},
#    {'entity_type': 'person', 'value': 'Roxo'},
#    {'entity_type': 'person', 'value': 'Caitlyn Jenner'},
#    {'entity_type': 'person', 'value': 'Soul Ja Boy'},
#    {'entity_type': 'person', 'value': 'Rich The Kid'},
#    {'entity_type': 'person', 'value': 'Kazumi'},
#    {'entity_type': 'person', 'value': 'Ivana Knöll'},
#    {'entity_type': 'location', 'value': 'Miami'},
#    {'entity_type': 'date', 'value': 'May 25-26'},
#    {'entity_type': 'person', 'value': 'Sahil Arora'},
#    {'entity_type': 'website', 'value': 'pump.fun'},
#    {'entity_type': 'person', 'value': 'Sophia Hutchins'},
#    {'entity_type': 'person', 'value': 'Gigantic-Cassocked-Rebirth (GCR)'},
#    {'entity_type': 'person',
#     'value': 'Magazine: Meme coins: Betrayal of crypto’s ideals… or its true purpose?'}]},
#  {'content': '5',
#   'entities': [{'entity_type': 'company', 'value': 'Sphere Labs'},
#    {'entity_type': 'cryptocurrency', 'value': 'Telegram'},
#    {'entity_type': 'cryptocurrency', 'value': 'Unibet'},
#    {'entity_type': 'cryptocurrency', 'value': 'CoinGecko'},
#    {'entity_type': 'company', 'value': 'Ripple Labs'},
#    {'entity_type': 'company', 'value': 'Standard Diamond Co.'},
#    {'entity_type': 'date', 'value': 'May 27'},
#    {'entity_type': 'date', 'value': '2024'},
#    {'entity_type': 'place', 'value': 'United States'},
#    {'entity_type': 'place', 'value': 'euro-denominated bank account'},
#    {'entity_type': 'place', 'value': 'India'}]},
#  {'content': '6',
#   'entities': [{'entity_type': 'cryptocurrency', 'value': 'crypto'},
#    {'entity_type': 'company', 'value': 'Robinhood Crypto'},
#    {'entity_type': 'place', 'value': 'United States'},
#    {'entity_type': 'date', 'value': 'March 2024'},
#    {'entity_type': 'company', 'value': 'BDC Consulting'}]},
#  {'content': '7',
#   'entities': [{'entity_type': 'person', 'value': 'Steve Chen'},
#    {'entity_type': 'company', 'value': 'YouTube'},
#    {'entity_type': 'cryptocurrency', 'value': 'memecoin'},
#    {'entity_type': 'cryptocurrency', 'value': 'Pajamas (PAJAMAS)'},
#    {'entity_type': 'blockchain', 'value': 'Solana'},
#    {'entity_type': 'date', 'value': 'May 27'},
#    {'entity_type': 'currency', 'value': 'DOGE'},
#    {'entity_type': 'person', 'value': 'X'},
#    {'entity_type': 'technology', 'value': 'artificial intelligence'},
#    {'entity_type': 'location', 'value': 'Taiwan'},
#    {'entity_type': 'cryptocurrency', 'value': 'Dogecoin'},
#    {'entity_type': 'cryptocurrency', 'value': 'CatCoin (CAT)'},
#    {'entity_type': 'company', 'value': 'BitForex'},
#    {'entity_type': 'project', 'value': 'Popcat (POPCAT)'},
#    {'entity_type': 'currency', 'value': 'CAT'},
#    {'entity_type': 'currency', 'value': 'POPCAT'},
#    {'entity_type': 'currency', 'value': 'CAT'}]},
#  {'content': '9',
#   'entities': [{'entity_type': 'cryptocurrency', 'value': 'Bitcoin'},
#    {'entity_type': 'cryptocurrency', 'value': 'Ethereum'},
#    {'entity_type': 'exchange', 'value': 'Mt. Gox'},
#    {'entity_type': 'amount', 'value': '107,000 BTC'},
#    {'entity_type': 'amount', 'value': 'nearly $7.3 billion'},
#    {'entity_type': 'date', 'value': 'May 28'},
#    {'entity_type': 'amount', 'value': '$68,460'},
#    {'entity_type': 'organization', 'value': 'Whale Alert'},
#    {'entity_type': 'amount', 'value': '3,999 BTC'},
#    {'entity_type': 'amount', 'value': '32,499 BTC'},
#    {'entity_type': 'company', 'value': 'Arkham Intelligence'},
#    {'entity_type': 'amount', 'value': '2,000 BTC'},
#    {'entity_type': 'amount', 'value': '107,547 BTC'},
#    {'entity_type': 'amount', 'value': '$7.29 billion'},
#    {'entity_type': 'crypto scam group', 'value': 'Inferno Drainer'},
#    {'entity_type': 'organization', 'value': 'SlowMist'},
#    {'entity_type': 'amount', 'value': '1,807 Ether'},
#    {'entity_type': 'amount', 'value': '$3,890'},
#    {'entity_type': 'person', 'value': 'Yu Xian'},
#    {'entity_type': 'crypto scam group', 'value': 'Scam Sniffer'},
#    {'entity_type': 'amount', 'value': '1,445 ETH'},
#    {'entity_type': 'percentage', 'value': '80%'},
#    {'entity_type': 'person', 'value': 'ZachXBT'},
#    {'entity_type': 'government', 'value': 'Argentina'},
#    {'entity_type': 'government', 'value': 'El Salvador'},
#    {'entity_type': 'organization',
#     'value': 'National Securities Commission (CNV)'},
#    {'entity_type': 'organization',
#     'value': 'National Commission of Digital Assets (CNAD)'},
#    {'entity_type': 'person', 'value': 'Roberto Silva'},
#    {'entity_type': 'person', 'value': 'Patricia Boedo'},
#    {'entity_type': 'person', 'value': 'Juan Carlos Reyes'},
#    {'entity_type': 'person', 'value': 'Diana Mondino'},
#    {'entity_type': 'person', 'value': 'Geraint Price'},
#    {'entity_type': 'person', 'value': 'Sam Bourgi'},
#    {'entity_type': 'person', 'value': 'Felix Ng'}]},
#  {'content': '10',
#   'entities': [{'entity_type': 'company', 'value': 'Radix'},
#    {'entity_type': 'platform', 'value': 'Token Trek'},
#    {'entity_type': 'currency', 'value': 'XRD'},
#    {'entity_type': 'currency', 'value': 'USD Coin'},
#    {'entity_type': 'currency', 'value': 'Tether'},
#    {'entity_type': 'currency', 'value': 'wrapped Bitcoin'},
#    {'entity_type': 'currency', 'value': 'Ether'},
#    {'entity_type': 'protocol', 'value': 'Maya Protocol'},
#    {'entity_type': 'blockchain', 'value': 'Ethereum'},
#    {'entity_type': 'blockchain', 'value': 'THORChain'},
#    {'entity_type': 'blockchain', 'value': 'Kujira'},
#    {'entity_type': 'blockchain', 'value': 'Arbitrum'},
#    {'entity_type': 'date', 'value': '2024'},
#    {'entity_type': 'date', 'value': 'March 2024'},
#    {'entity_type': 'date', 'value': 'first quarter of 2024'}]},
#  {'content': '11',
#   'entities': [{'entity_type': 'cryptocurrency', 'value': 'Solana'},
#    {'entity_type': 'date', 'value': 'May 27'},
#    {'entity_type': 'price', 'value': '$168'},
#    {'entity_type': 'price', 'value': '$210'},
#    {'entity_type': 'price', 'value': '$171'},
#    {'entity_type': 'date', 'value': '2023'},
#    {'entity_type': 'date', 'value': 'March 2024'},
#    {'entity_type': 'date', 'value': 'September 2021'},
#    {'entity_type': 'date', 'value': 'December'},
#    {'entity_type': 'place', 'value': 'SolChick'},
#    {'entity_type': 'metric', 'value': '1,504 TPS'},
#    {'entity_type': 'company', 'value': 'CoinGecko'},
#    {'entity_type': 'company', 'value': 'Ethereum'}]},
#  {'content': '12',
#   'entities': [{'entity_type': 'organization', 'value': 'Libertarian Party'},
#    {'entity_type': 'location', 'value': 'United States'},
#    {'entity_type': 'person', 'value': 'Chase Oliver'},
#    {'entity_type': 'person', 'value': 'Donald Trump'},
#    {'entity_type': 'person', 'value': 'Robert F. Kennedy Jr.'},
#    {'entity_type': 'date', 'value': 'Memorial Day Weekend'},
#    {'entity_type': 'date', 'value': 'May 26'},
#    {'entity_type': 'date', 'value': 'November 2024'},
#    {'entity_type': 'person', 'value': 'Joe Biden'},
#    {'entity_type': 'person', 'value': 'Ross Ulbricht'},
#    {'entity_type': 'organization', 'value': 'Cointelegraph'},
#    {'entity_type': 'person', 'value': 'Mike ter Maat'},
#    {'entity_type': 'person', 'value': 'Sam Bankman-Fried'},
#    {'entity_type': 'organization', 'value': 'FTX'},
#    {'entity_type': 'date', 'value': '2016'},
#    {'entity_type': 'date', 'value': '2024'},
#    {'entity_type': 'person', 'value': 'Corbin Sabol'}]},
#  {'content': '13',
#   'entities': [{'entity_type': 'company', 'value': 'Gopax'},
#    {'entity_type': 'company', 'value': 'Binance'},
#    {'entity_type': 'place', 'value': 'South Korean'},
#    {'entity_type': 'date', 'value': 'August 2023'},
#    {'entity_type': 'date', 'value': 'May 27'},
#    {'entity_type': 'company', 'value': 'Genesis Global'},
#    {'entity_type': 'currency', 'value': 'South Korean won'},
#    {'entity_type': 'currency', 'value': '$51.4 million'},
#    {'entity_type': 'currency', 'value': 'BTC'},
#    {'entity_type': 'currency', 'value': '$68,460'},
#    {'entity_type': 'company', 'value': 'Korean Times'},
#    {'entity_type': 'company', 'value': 'Three Arrows Capital'},
#    {'entity_type': 'company', 'value': 'GoFi'},
#    {'entity_type': 'company',
#     'value': 'United States Securities and Exchange Commission'},
#    {'entity_type': 'company', 'value': 'Financial Service Committee'},
#    {'entity_type': 'company', 'value': 'Digital Currency Group'},
#    {'entity_type': 'judge', 'value': 'Sean Lane'},
#    {'entity_type': 'company', 'value': 'Binance.US'}]},
#  {'content': 14,
#   'entities': [{'entity_type': 'company', 'value': 'Fiat24'},
#    {'entity_type': 'technology', 'value': 'Web3'},
#    {'entity_type': 'token', 'value': 'ERC-721'},
#    {'entity_type': 'token', 'value': 'ERC-20'},
#    {'entity_type': 'technology', 'value': 'NFT'},
#    {'entity_type': 'technology', 'value': 'smart contracts'},
#    {'entity_type': 'location', 'value': 'Switzerland'},
#    {'entity_type': 'token', 'value': 'IBAN'},
#    {'entity_type': 'token', 'value': 'EUR'},
#    {'entity_type': 'token', 'value': 'CHF'},
#    {'entity_type': 'token', 'value': 'USD'},
#    {'entity_type': 'token', 'value': 'F24'},
#    {'entity_type': 'blockchain', 'value': 'Ethereum'},
#    {'entity_type': 'blockchain', 'value': 'Arbitrum'},
#    {'entity_type': 'token', 'value': 'ARB'},
#    {'entity_type': 'payment network', 'value': 'SWIFT'},
#    {'entity_type': 'payment network', 'value': 'SEPA'},
#    {'entity_type': 'payment network', 'value': 'Visa'},
#    {'entity_type': 'payment network', 'value': 'Mastercard'}]},
#  {'content': '15',
#   'entities': [{'entity_type': 'cryptocurrency', 'value': 'CAT'},
#    {'entity_type': 'place', 'value': 'Sol'},
#    {'entity_type': 'company', 'value': 'Hyperliquid'},
#    {'entity_type': 'cryptocurrency', 'value': 'ORDI'},
#    {'entity_type': 'cryptocurrency', 'value': 'ETHFI'},
#    {'entity_type': 'person', 'value': 'ZachXBT'},
#    {'entity_type': 'person', 'value': 'Gigantic-Cassocked-Rebirth (GCR)'}]},
#  {'content': '16',
#   'entities': [{'entity_type': 'company', 'value': 'Nomura Holdings'},
#    {'entity_type': 'company', 'value': 'GMO Internet Group'},
#    {'entity_type': 'company', 'value': 'Laser Digital Holdings'},
#    {'entity_type': 'person', 'value': 'Kentaro Okuda'},
#    {'entity_type': 'country', 'value': 'Japan'},
#    {'entity_type': 'country', 'value': 'United States'},
#    {'entity_type': 'currency', 'value': 'Japanese yen'},
#    {'entity_type': 'currency', 'value': 'United States dollar'},
#    {'entity_type': 'organization', 'value': 'Financial Services Agency (FSA)'},
#    {'entity_type': 'product', 'value': 'stablecoins'},
#    {'entity_type': 'product', 'value': 'digital assets'},
#    {'entity_type': 'product', 'value': 'JPY/USD stablecoin business'},
#    {'entity_type': 'product', 'value': 'non-securities'},
#    {'entity_type': 'product', 'value': 'TerraUSD'},
#    {'entity_type': 'date', 'value': '2022'},
#    {'entity_type': 'event',
#     'value': 'bill labeled stablecoins as non-securities'},
#    {'entity_type': 'event',
#     'value': 'establishment of clear and robust regulatory framework governing stablecoins'},
#    {'entity_type': 'event', 'value': 'collapsing of TerraUSD'},
#    {'entity_type': 'event', 'value': 'dramatic price implosion of stablecoin'},
#    {'entity_type': 'event',
#     'value': 'potential to enhance digital asset accessibility and innovation in Japanese financial landscape'},
#    {'entity_type': 'event',
#     'value': 'warnings about algorithmic stablecoins from Japan’s Financial Services Agency'}]},
#  {'content': '17',
#   'entities': [{'entity_type': 'cryptocurrency', 'value': 'Ether'},
#    {'entity_type': 'cryptocurrency', 'value': 'ETH'},
#    {'entity_type': 'price', 'value': '$3,890'},
#    {'entity_type': 'price', 'value': '$4,000'},
#    {'entity_type': 'crypto trader', 'value': 'Jelle'},
#    {'entity_type': 'cryptocurrency', 'value': 'Bitcoin'},
#    {'entity_type': 'price', 'value': '$68,460'},
#    {'entity_type': 'exchange', 'value': 'TradingView'},
#    {'entity_type': 'company', 'value': 'SEC'},
#    {'entity_type': 'company', 'value': 'ETFs'},
#    {'entity_type': 'person', 'value': 'Arthur Cheong'},
#    {'entity_type': 'company', 'value': 'DeFiance Capital'},
#    {'entity_type': 'price', 'value': '$4,500'},
#    {'entity_type': 'price', 'value': '$3,956'},
#    {'entity_type': 'crypto analyst', 'value': 'Rekt Capital'},
#    {'entity_type': 'price', 'value': '$10K'},
#    {'entity_type': 'date', 'value': 'May 27'},
#    {'entity_type': 'date', 'value': 'May 20'},
#    {'entity_type': 'date', 'value': 'May 26'},
#    {'entity_type': 'number', 'value': '27%'},
#    {'entity_type': 'number', 'value': '0.98%'},
#    {'entity_type': 'number', 'value': '4.4%'},
#    {'entity_type': 'number', 'value': '1.45%'},
#    {'entity_type': 'number', 'value': '0.57%'},
#    {'entity_type': 'number', 'value': '$433 million'}]},
#  {'content': '18',
#   'entities': [{'entity_type': 'cryptocurrency', 'value': 'WAVES'},
#    {'entity_type': 'cryptocurrency', 'value': 'ETH'}]},
#  {'content': 19,
#   'entities': [{'entity_type': 'cryptocurrency', 'value': 'Ether'},
#    {'entity_type': 'cryptocurrency', 'value': 'ETH'},
#    {'entity_type': 'amount', 'value': '1,807'},
#    {'entity_type': 'amount', 'value': '3,890'},
#    {'entity_type': 'amount', 'value': '6.91 million'},
#    {'entity_type': 'date', 'value': 'May 26'},
#    {'entity_type': 'company', 'value': 'Inferno Drainer'},
#    {'entity_type': 'company', 'value': 'SlowMist'},
#    {'entity_type': 'company', 'value': 'Scam Sniffer'},
#    {'entity_type': 'person', 'value': 'Yu Xian'},
#    {'entity_type': 'person', 'value': 'ZachXBT'},
#    {'entity_type': 'website', 'value': 'Cointelegraph'},
#    {'entity_type': 'percentage', 'value': '80%'},
#    {'entity_type': 'percentage', 'value': '20%'},
#    {'entity_type': 'event', 'value': 'permit phishing attack'},
#    {'entity_type': 'technology', 'value': 'Ethereum permits'},
#    {'entity_type': 'technology', 'value': 'EIP-2612'},
#    {'entity_type': 'location', 'value': 'United States'}]},
#  {'content': '20',
#   'entities': [{'entity_type': 'cryptocurrency', 'value': 'MAGA'},
#    {'entity_type': 'person', 'value': 'Donald Trump'},
#    {'entity_type': 'company', 'value': 'Lookonchain'},
#    {'entity_type': 'person', 'value': 'Datawallet'},
#    {'entity_type': 'cryptocurrency', 'value': 'SOL'},
#    {'entity_type': 'cryptocurrency', 'value': 'Ether'},
#    {'entity_type': 'person', 'value': 'Dominium'}]}]

# %%
from rag.retriever import QueryMetaExtractor

QueryMetaExtractor().generate_response("should i yolo in?")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Library/Caches/pypoetry/virtualenvs/rag-system-_6t_t_f9-py3.10/lib/python3.10/site-packages/langchain_core/output_parsers/openai_functions.py:73, in JsonOutputFunctionsParser.parse_result(self, result, partial)
#      72 try:
# ---> 73     function_call = message.additional_kwargs["function_call"]
#      74 except KeyError as exc:
#
# KeyError: 'function_call'
#
# During handling of the above exception, another exception occurred:
#
# OutputParserException                     Traceback (most recent call last)
# Cell In[10], line 3
#       1 from rag.retriever import QueryMetaExtractor
# ----> 3 QueryMetaExtractor().generate_response("should i yolo in?")
#
# File ~/Documents/mai-repos/weaviate_pipeline/notebooks/../rag/query_meta_extractor.py:19, in QueryMetaExtractor.generate_response(query)
#      16 chain = prompt | model.bind(functions=openai_functions) | parser
#      18 current_date = datetime.now().strftime(format="%Y-%m-%d")
# ---> 19 return chain.invoke({"current_date":current_date,  "user_query": query})
#
# File ~/Library/Caches/pypoetry/virtualenvs/rag-system-_6t_t_f9-py3.10/lib/python3.10/site-packages/langchain_core/runnables/base.py:2499, in RunnableSequence.invoke(self, input, config)
#    2497 try:
#    2498     for i, step in enumerate(self.steps):
# -> 2499         input = step.invoke(
#    2500             input,
#    2501             # mark each step as a child run
#    2502             patch_config(
#    2503                 config, callbacks=run_manager.get_child(f"seq:step:{i+1}")
#    2504             ),
#    2505         )
#    2506 # finish the root run
#    2507 except BaseException as e:
#
# File ~/Library/Caches/pypoetry/virtualenvs/rag-system-_6t_t_f9-py3.10/lib/python3.10/site-packages/langchain_core/output_parsers/base.py:169, in BaseOutputParser.invoke(self, input, config)
#     165 def invoke(
#     166     self, input: Union[str, BaseMessage], config: Optional[RunnableConfig] = None
#     167 ) -> T:
#     168     if isinstance(input, BaseMessage):
# --> 169         return self._call_with_config(
#     170             lambda inner_input: self.parse_result(
#     171                 [ChatGeneration(message=inner_input)]
#     172             ),
#     173             input,
#     174             config,
#     175             run_type="parser",
#     176         )
#     177     else:
#     178         return self._call_with_config(
#     179             lambda inner_input: self.parse_result([Generation(text=inner_input)]),
#     180             input,
#     181             config,
#     182             run_type="parser",
#     183         )
#
# File ~/Library/Caches/pypoetry/virtualenvs/rag-system-_6t_t_f9-py3.10/lib/python3.10/site-packages/langchain_core/runnables/base.py:1626, in Runnable._call_with_config(self, func, input, config, run_type, **kwargs)
#    1622     context = copy_context()
#    1623     context.run(var_child_runnable_config.set, child_config)
#    1624     output = cast(
#    1625         Output,
# -> 1626         context.run(
#    1627             call_func_with_variable_args,  # type: ignore[arg-type]
#    1628             func,  # type: ignore[arg-type]
#    1629             input,  # type: ignore[arg-type]
#    1630             config,
#    1631             run_manager,
#    1632             **kwargs,
#    1633         ),
#    1634     )
#    1635 except BaseException as e:
#    1636     run_manager.on_chain_error(e)
#
# File ~/Library/Caches/pypoetry/virtualenvs/rag-system-_6t_t_f9-py3.10/lib/python3.10/site-packages/langchain_core/runnables/config.py:347, in call_func_with_variable_args(func, input, config, run_manager, **kwargs)
#     345 if run_manager is not None and accepts_run_manager(func):
#     346     kwargs["run_manager"] = run_manager
# --> 347 return func(input, **kwargs)
#
# File ~/Library/Caches/pypoetry/virtualenvs/rag-system-_6t_t_f9-py3.10/lib/python3.10/site-packages/langchain_core/output_parsers/base.py:170, in BaseOutputParser.invoke.<locals>.<lambda>(inner_input)
#     165 def invoke(
#     166     self, input: Union[str, BaseMessage], config: Optional[RunnableConfig] = None
#     167 ) -> T:
#     168     if isinstance(input, BaseMessage):
#     169         return self._call_with_config(
# --> 170             lambda inner_input: self.parse_result(
#     171                 [ChatGeneration(message=inner_input)]
#     172             ),
#     173             input,
#     174             config,
#     175             run_type="parser",
#     176         )
#     177     else:
#     178         return self._call_with_config(
#     179             lambda inner_input: self.parse_result([Generation(text=inner_input)]),
#     180             input,
#     181             config,
#     182             run_type="parser",
#     183         )
#
# File ~/Library/Caches/pypoetry/virtualenvs/rag-system-_6t_t_f9-py3.10/lib/python3.10/site-packages/langchain_core/output_parsers/openai_functions.py:78, in JsonOutputFunctionsParser.parse_result(self, result, partial)
#      76         return None
#      77     else:
# ---> 78         raise OutputParserException(f"Could not parse function call: {exc}")
#      79 try:
#      80     if partial:
#
# OutputParserException: Could not parse function call: 'function_call'
